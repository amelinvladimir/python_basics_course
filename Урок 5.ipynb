# %%
# Комментарий

# %%
name = input("Введите ваше имя") # Запрашиваем у пользователя ввести его имя
# Out:
# Введите ваше имя В

# %%
name = input("Введите ваше имя") # input выводит на экран текст, который вы ей передадите и затем попросит пользователя ввести текст. Введенный текст сохранит в переменной name

# %%
# input выводит на экран текст, который вы ей передадите и затем попросит пользователя ввести текст. 
# Введенный текст сохранит в переменной name.
name = input("Введите ваше имя")

# %%
"""
input выводит на экран текст, который вы ей передадите и затем попросит пользователя ввести текст. 
Введенный текст сохранит в переменной name.
"""
name = input("Введите ваше имя")
# Out:
# Введите ваше имя В
