# %%
a, b = 10, 0

if b != 0:
    print(f"Результат: {a / b}")
else:
    print("Ошибка: деление на ноль запрещено!")

# %%
a, b = 10, 2

if b != 0:
    print(f"Результат: {a / b}")

# %%
hour = int(input("Который час? "))

if hour < 6:
    greeting = "Доброй ночи"
elif hour < 12:
    greeting = "Доброе утро"
elif hour < 18:
    greeting = "Добрый день"
else:
    greeting = "Добрый вечер"

print(f"{greeting}! Сейчас {hour} часов.")

# %%
age = int(input("Введите полное количество лет: "))
status = "совершеннолетний" if age >= 18 else "несовершеннолетний"
print(f"Человек {age} лет — {status}")

# %%
temp = 25

if temp < 0:
    print(f"❄️ {temp}°C — холодно")
elif temp < 15:
    print(f"☁️ {temp}°C — прохладно")
elif temp < 28:
    print(f"🌤 {temp}°C — комфортно")
else:
    print(f"☀️ {temp}°C — жарко")

# %%
if int(input("Введите первое число: ")) > 1:
    print("Первое число больше единицы")
elif int(input("Введите второе число: ")) > 1:
    print("Второе число больше единицы")
else:
    print("Оба числа меньше или равны единице")

# %%
i = int(input("Введите число от 1 до 6: "))

if i <= 3:
    i += 2
    i *= 3
    i -= 1
    print(f"i = {i}")

# %%
i = int(input("Введите число от 1 до 6: "))

if i <= 3:
    i += 2
    i *= 3
    i -= 1
    print(f"i = {i}")
