# %%
print('Строка в одинарных кавычках')
# Out:
# Строка в одинарных кавычках

# %%
a = 'Строка в одинарных кавычках'
print(a)
# Out:
# Строка в одинарных кавычках

# %%
print("Строка в двойных кавычках")
# Out:
# Строка в двойных кавычках

# %%
print("""Текст
из
нескольких
строк
:)
""")
# Out:
# Текст
# из
# нескольких
# строк
# :)

# %%
print('''Текст
из
нескольких
строк 
в одинарных кавычках
:)
''')
# Out:
# Текст
# из
# нескольких
# строк
# в одинарных кавычках
# :)

# %%
print('Он сказал: "Приходите завтра".')
# Out:
# Он сказал: "Приходите завтра".

# %%
print('В этом предложении 'слово' в одинарных кавычках')
# Out:
#   Cell In[29], line 1
#     print('В этом предложении 'слово' в одинарных кавычках')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('В этом предложении \'слово\' в одинарных кавычках')
# Out:
# В этом предложении 'слово' в одинарных кавычках

# %%
print("В этом предложении 'слово' в одинарных кавычках")
# Out:
# В этом предложении 'слово' в одинарных кавычках

# %%
print("Он сказал: \"Приходите завтра\".")
# Out:
# Он сказал: "Приходите завтра".

# %%
print('C:\Users\Name\Documents\file.txt')
# Out:
#   Cell In[33], line 1
#     print('C:\Users\Name\Documents\file.txt')
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
print("C:\\Use\brs\\Name\\Documents\\file.txt")
# Out:
# C:\Usrs\Name\Documents\file.txt

# %%
print("Хорошо \
живет \
на свете \
Винни-Пух")
# Out:
# Хорошо живет на свете Винни-Пух

# %%
print("Хорошо 
живет 
на свете 
Винни-Пух")
# Out:
#   Cell In[37], line 1
#     print("Хорошо
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("""Хорошо 
живет 
на свете 
Винни-Пух""")
# Out:
# Хорошо
# живет
# на свете
# Винни-Пух

# %%
print("""Хорошо \
живет \
на свете \
Винни-Пух""")
# Out:
# Хорошо живет на свете Винни-Пух

# %%
print("Хорошо \nживет \nна свете \nВинни-Пух")
# Out:
# Хорошо
# живет
# на свете
# Винни-Пух

# %%
print("\110\145\154\154\157")
# Out:
# Hello

# %%
print("\x30\x31\x32")
# Out:
# 012

# %%
print("\u005e\u01d1")
# Out:
# ^Ǒ

# %%
print("\U0001F600")
# Out:
# 😀

# %%
print("\x5e")
print("\u005e")
print("\U0000005e")
# Out:
# ^
# ^
# ^

# %%
teleg_text = input("Введите текст телеграммы: ")
print("Длина телеграммы: ") 
print(len(teleg_text))
# Out:
# Введите текст телеграммы:  приеду завтра в 20-00, встречай.
# Длина телеграммы:
# 32

# %%
teleg_text = input("Введите текст телеграммы: ")
print("Длина телеграммы: ") 
print(len(teleg_text))

teleg_text_wo_points = teleg_text.replace(".", "")
print("Длина телеграммы без точек: ") 
print(len(teleg_text_wo_points))
# Out:
# Введите текст телеграммы:  приеду завтра в 20-00, встречай.
# Длина телеграммы:
# 32
# Длина телеграммы без точек:
# 31

# %%
teleg_text = input("Введите текст телеграммы: ")
print("Длина телеграммы: " + len(teleg_text))
# Out:
# Введите текст телеграммы:  приеду завтра в 20-00, встречай.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 teleg_text = input("Введите текст телеграммы: ")
# ----> 2 print("Длина телеграммы: " + len(teleg_text))
#
# TypeError: can only concatenate str (not "int") to str

# %%
teleg_text = input("Введите текст телеграммы: ")
print("Длина телеграммы: " + str(len(teleg_text)))
# Out:
# Введите текст телеграммы:  приеду завтра в 20-00, встречай.
# Длина телеграммы: 32

# %%
teleg_text = input("Введите текст телеграммы: ")
print(f'Длина телеграммы: {len(teleg_text)}')
# Out:
# Введите текст телеграммы:  приеду завтра в 20-00, встречай.
# Длина телеграммы: 32

# %%
teleg_text = input("Введите текст телеграммы: ")
print(f"""Длина телеграммы: {len(teleg_text)}
Длина телеграммы без точек: {len(teleg_text.replace(".", ""))}""")
# Out:
# Введите текст телеграммы:  приеду завтра в 20-00, встречай.
# Длина телеграммы: 32
# Длина телеграммы без точек: 31

# %%
s = "Купи слона "
a = s * 3
print(a)
# Out:
# Купи слона Купи слона Купи слона

# %%
name = 'мир'
print(f'Повторяется:{f' привет {name}' * 3}')
# Out:
# Повторяется: привет мир привет мир привет мир

# %%
name = 'мир'
b = f'Повторяется:{f' привет {name}' * 3}'
print(b.center(100))
# Out:
#                            Повторяется: привет мир привет мир привет мир

# %%
text = input("Введите текст: ")
words = text.split()
print(words[0])
print(words[1])
# Out:
# Введите текст:  Раз два три, елочка гори
# Раз
# два

# %%
text = input("Введите текст: ")
words = text.split()
print(len(words))
# Out:
# Введите текст:  Раз два три, елочка гори
# 5

# %%
print("spam " "eggs")
# Out:
# spam eggs

# %%
a = ("spam " "eggs" " ф")
print(a)
# Out:
# spam eggs ф

# %%
s = "Что умеет python?"
print(s[0])
print(s[1])
print(s[2])
print(s[3])
# Out:
# Ч
# т
# о

# %%
s = "Что умеет python?"
print(s[0:1])
print(s[0:2])
print(s[0:3])
print(s[0:4])
# Out:
# Ч
# Чт
# Что
# Что

# %%
s = "Что умеет python?"
print(s[6:6])
print(s[5:6])
print(s[4:6])
print(s[3:6])
# Out:
# м
# ум
#  ум

# %%
s = "Что умеет python?"
print(s[0:])
print(s[1:])
print(s[2:])
print(s[3:])
# Out:
# Что умеет python?
# то умеет python?
# о умеет python?
#  умеет python?

# %%
s = "Что умеет python?"
print(s[:8])
print(s[:7])
print(s[:6])
print(s[:5])
# Out:
# Что умее
# Что уме
# Что ум
# Что у

# %%
s = "Что умеет python?"
print(s[:])
# Out:
# Что умеет python?

# %%
s = "Что умеет python?"
print(s[-1:])
print(s[-2:])
print(s[-3:])
print(s[-4:])
# Out:
# ?
# n?
# on?
# hon?

# %%
s = "Что умеет python?"
print(s[-5:])
print(s[-5:-1])
print(s[-5:-2])
print(s[-5:-3])
# Out:
# thon?
# thon
# tho
# th

# %%
s = "Что умеет python?"
print(s[0:-1:2])
print(s[::2])
print(s[::-1])
# Out:
# Чоуетpto
# Чоуетpto?
# ?nohtyp теему отЧ

# %%
s = "раз два три"
print("раз" in s)
print("четыре" in s)
print("пять" not in s)
# Out:
# True
# False
# True
