# %%
for i in range(10):
    print(i)

# %%
list(range(10))

# %%
list(range(3, 10))

# %%
list(range(3, 10, 3))

# %%
list(range(-1, -100, -30))

# %%
a = ['Mary', 'had', 'a', 'little', 'lamb']
for i in range(len(a)):
    print(i, a[i])

# %%
range(10)

# %%
sum(range(4))  # 0 + 1 + 2 + 3
