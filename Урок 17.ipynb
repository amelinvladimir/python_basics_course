# %%
while True:
    pass   # Ожидание прерывания клавиатуры (Ctrl+C)

# %%
def initlog(*args):
    pass   # Не забудьте реализовать это!

initlog()

# %%
def initlog(*args):
    ...    # Не забудьте реализовать это!

initlog()
