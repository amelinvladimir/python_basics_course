# %%
1+1

# %%
5-3

# %%
-5+3

# %%
5*3

# %%
10/3

# %%
10/2

# %%
10//3

# %%
5%2

# %%
4**2

# %%
2+3*5+1

# %%
(2+3)*5+1

# %%
i = 1
print(f'{i} - {type(i)}')
i = 1.0
print(f'{i} - {type(i)}')
i = 1j
print(f'{i} - {type(i)}')

# %%
i = 1 
print(f'{i} - {type(i)}')
j = float(i)
print(f'{j} - {type(j)}')
k = complex(j)
print(f'{k} - {type(k)}')

# %%
x = 1
x += 2 # эквивалентно x = x + 2
print(x)
x -= 1 # эквивалентно x = x - 1
print(x)
x *= 2 # эквивалентно x = x * 2
print(x)
x /= 2 # эквивалентно x = x / 2
print(x)
x **= 2 # эквивалентно x = x ** 2
print(x)
x %= 3 # эквивалентно x = x % 3
print(x)

# %%
0.1+0.2
